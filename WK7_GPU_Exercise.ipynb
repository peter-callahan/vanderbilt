# %% [markdown]
# <a href="https://colab.research.google.com/github/peter-callahan/vanderbilt/blob/main/WK7_GPU_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# https://github.com/pytorch/examples/blob/main/mnist/main.py

# %%
# %cd gdrive/My\ Drive/Colab\ Notebooks/
# %ls
# Out:
#  employee_churn_upload_peter_callahan_a6.ipynb
#  employee_churn_upload_peter_callahan.ipynb
#  main.py
# 'Michigan Real Estate Script - Realty API.ipynb'
#  real-estate-project-overview.ipynb
#  Untitled
#  week3_class_exercise_part1_solution.ipynb
# 'week3_class_exercise_ZHANG (1).ipynb'
#  week3_class_exercise_ZHANG.ipynb
#  week4_assignment_part1.ipynb
#  week4_class_demo.ipynb
#  WK7-GPU-Exercise.ipynb

# %%
! nvidia-smi
# Out:
# Thu Jun 23 12:21:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.__version__
# Out:
# '1.11.0+cu113'

# %%
# %run main.py
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.282550
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.385150
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.897099
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.617033
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.364887
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.426826
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.272236
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.643788
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.234563
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.284866
# ...
